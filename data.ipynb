# %% [markdown]
# ## Tally of Merch Orders (1st Batch)

# %%
from merch import Merch

# Initialize the location of pre-order file
merch = Merch("merch-pre-order.xlsx")

# %%
merch.process_data()
merch.print_all_data()
# Out:
# Smiski
# Sablay Smiski: 21
# Lock In Smiski: 35
# J*bless Smiski: 24
# Sweater Smiski: 7
#
# Retro
# Iskeri Snupi: 12
# CS Week Lights: 3
# Shadow Monster: 14
# Cassette: 17
# Koket Dino: 5
#
# Meme
# Grin 1: 6
# Grin 2: 3
# Nerdy Neko: 22
# Ragebaited: 9
# Tired: 6
#
# Python vs C++
# Python Enjoyer: 42
# C++ Enjoyer: 25
#
# DCS-Chan and Cherisse
# Flop: 3
# Homeless: 0
# Tara Nomi: 13
# Finger Bite: 10
#
# JJ and Inigo
# Absolute Cinema: 8
# Sleep: 16
# Low Cortisol: 14
# Holy Airball: 11
# Clown: 1
# Speed Please: 0
#
# Keychain
# Abbey Road: 6
# Cherisse: 6
# Shadow Gate: 9
#
# Pins
# Star DCS: 0
# Pixel DCS: 12
# OJ is a Curseword: 12
# Inverted DCS: 24
#
# Lanyard
# White Cream: 0
# Dark Tendrils: 18
# Dark Red Fiery: 0
# Red Fiery: 0
# Dark Tendrils/White Cream: 6
# Dark Red Fiery/Red Fiery: 3
#
# ID Case
# Levitate: 9
# Windows XP: 36
#
# Tote Bag
# DCS-Chan: 15
#
# Can We Do Better
# Can We Do Better Green (XS): 6
# Can We Do Better Green (S): 3
# Can We Do Better Green (M): 21
# Can We Do Better Green (L): 12
# Can We Do Better Green (XL): 3
#
# Can We Do Better Orange (XS): 0
# Can We Do Better Orange (S): 9
# Can We Do Better Orange (M): 0
# Can We Do Better Orange (L): 3
# Can We Do Better Orange (XL): 3
#
# Can We Do Better Red (XS): 3
# Can We Do Better Red (S): 0
# Can We Do Better Red (M): 6
# Can We Do Better Red (L): 9
# Can We Do Better Red (XL): 6
#
# Brute Force Club
# Brute Force Dark (XS): 0
# Brute Force Dark (S): 3
# Brute Force Dark (M): 3
# Brute Force Dark (L): 9
# Brute Force Dark (XL): 3
#
# Brute Force Light (XS): 3
# Brute Force Light (S): 3
# Brute Force Light (M): 6
# Brute Force Light (L): 6
# Brute Force Light (XL): 0
#
#
# Note that these values are automatically added to main list!
#
# Gacha Stickers
# Sablay Smiski: 3
# Lock In Smiski: 2
# Sweater Smiski: 1
# Nerdy Neko: 1
# Tired: 3
# C++ Enjoyer: 1
# Shadow Monster: 2
# Cassette: 2
# Koket Dino: 2
# Tara Nomi: 1
# Finger Bite: 1
# Absolute Cinema: 2
# Sleep: 1
# Low Cortisol: 2
# Holy Airball: 2
# Clown: 1
