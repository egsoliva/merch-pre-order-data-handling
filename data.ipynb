# %% [markdown]
# ## Tally of Merch Orders (1st Batch)

# %%
from merch import Merch

# Initialize the location of pre-order file
merch = Merch("merch-pre-order.xlsx", 2, 38)

# %%
merch.process_data()
merch.print_all_data()
# Out:
# Smiski
# Sablay Smiski: 6
# Lock In Smiski: 11
# J*bless Smiski: 10
# Sweater Smiski: 2
#
# Retro
# Iskeri Snupi: 4
# CS Week Lights: 1
# Shadow Monster: 6
# Cassette: 5
# Koket Dino: 1
#
# Meme
# Grin 1: 2
# Grin 2: 1
# Nerdy Neko: 7
# Ragebaited: 3
# Tired: 1
#
# Python vs C++
# Python Enjoyer: 14
# C++ Enjoyer: 9
#
# DCS-Chan and Cherisse
# Flop: 1
# Homeless: 1
# Tara Nomi: 4
# Finger Bite: 3
#
# JJ and Inigo
# Absolute Cinema: 2
# Sleep: 6
# Low Cortisol: 4
# Holy Airball: 4
# Clown: 0
# Speed Please: 1
#
# Keychain
# Abbey Road: 2
# Cherisse: 2
# Shadow Gate: 3
#
# Lanyard
# White Cream: 0
# Dark Tendrils: 6
# Dark Red Fiery: 0
# Red Fiery: 0
# Dark Tendrils/White Cream: 2
# Dark Red Fiery/Red Fiery: 1
#
# Pins
# Star DCS: 0
# Pixel DCS: 4
# OJ is a Curseword: 4
# Inverted DCS: 8
#
# ID Case
# Levitate: 3
# Windows XP: 12
#
# Tote Bag
# DCS-Chan: 5
#
# Can We Do Better
# Can We Do Better Green (XS): 2
# Can We Do Better Green (S): 1
# Can We Do Better Green (M): 7
# ...

# %% [markdown]
# #### Second Batch

# %%
second_batch = Merch("merch-pre-order.xlsx", 39, 76)
second_batch.process_data()
second_batch.print_all_data()
second_batch.print_random_stickers()
# Out:
# Smiski
# Sablay Smiski: 8
# Lock In Smiski: 6
# J*bless Smiski: 5
# Sweater Smiski: 6
#
# Retro
# Iskeri Snupi: 3
# CS Week Lights: 0
# Shadow Monster: 2
# Cassette: 0
# Koket Dino: 4
#
# Meme
# Grin 1: 5
# Grin 2: 5
# Nerdy Neko: 9
# Ragebaited: 6
# Tired: 6
#
# Python vs C++
# Python Enjoyer: 2
# C++ Enjoyer: 1
#
# DCS-Chan and Cherisse
# Flop: 2
# Homeless: 3
# Tara Nomi: 0
# Finger Bite: 2
#
# JJ and Inigo
# Absolute Cinema: 1
# Sleep: 0
# Low Cortisol: 0
# Holy Airball: 4
# Clown: 0
# Speed Please: 3
#
# Keychain
# Abbey Road: 1
# Cherisse: 0
# Shadow Gate: 1
#
# Lanyard
# White Cream: 0
# Dark Tendrils: 2
# Dark Red Fiery: 0
# Red Fiery: 0
# Dark Tendrils/White Cream: 1
# Dark Red Fiery/Red Fiery: 0
#
# Pins
# Star DCS: 0
# Pixel DCS: 5
# OJ is a Curseword: 1
# Inverted DCS: 2
#
# ID Case
# Levitate: 1
# Windows XP: 2
#
# Tote Bag
# DCS-Chan: 2
#
# Can We Do Better
# Can We Do Better Green (XS): 0
# Can We Do Better Green (S): 0
# Can We Do Better Green (M): 6
# ...
